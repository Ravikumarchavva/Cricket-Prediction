# %%
import pandas as pd

# %%
deliveries = pd.read_parquet(r'C:\Users\amadh\OneDrive\Desktop\Project Series\Cricket-Prediction\historical_data\cricsheetSource\deliveries.parquet')
match_players = pd.read_parquet(r'C:\Users\amadh\OneDrive\Desktop\Project Series\Cricket-Prediction\historical_data\cricsheetSource\match_players.parquet')
matches = pd.read_parquet(r'C:\Users\amadh\OneDrive\Desktop\Project Series\Cricket-Prediction\historical_data\cricsheetSource\matches.parquet')

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794009 entries, 0 to 794008
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   match_id                794009 non-null  int64
#  1   season                  794009 non-null  object
#  2   start_date              794009 non-null  object
#  3   venue                   794009 non-null  object
#  4   innings                 794009 non-null  int64
#  5   ball                    794009 non-null  float64
#  6   batting_team            794009 non-null  object
#  7   bowling_team            794009 non-null  object
#  8   striker                 794009 non-null  object
#  9   non_striker             794009 non-null  object
#  10  bowler                  794009 non-null  object
#  11  runs_off_bat            794009 non-null  int64
#  12  extras                  794009 non-null  int64
#  13  wides                   32436 non-null   float64
# ...

# %%
deliveries.head()
# Out:
#    match_id   season  start_date                     venue  innings  ball  \
# 0   1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.1
# 1   1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.2
# 2   1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.3
# 3   1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.4
# 4   1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.5
#
#   batting_team bowling_team    striker non_striker  ... extras  wides  \
# 0    Australia    Sri Lanka   AJ Finch   M Klinger  ...      0    NaN
# 1    Australia    Sri Lanka   AJ Finch   M Klinger  ...      0    NaN
# 2    Australia    Sri Lanka   AJ Finch   M Klinger  ...      0    NaN
# 3    Australia    Sri Lanka  M Klinger    AJ Finch  ...      0    NaN
# 4    Australia    Sri Lanka  M Klinger    AJ Finch  ...      0    NaN
#
#    noballs  byes legbyes  penalty  wicket_type player_dismissed  \
# ...

# %%
match_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   team1_player1    3463 non-null   object
#  1   team1_player2    3463 non-null   object
#  2   team1_player3    3463 non-null   object
#  3   team1_player4    3463 non-null   object
#  4   team1_player5    3463 non-null   object
#  5   team1_player6    3463 non-null   object
#  6   team1_player7    3463 non-null   object
#  7   team1_player8    3463 non-null   object
#  8   team1_player9    3463 non-null   object
#  9   team1_player10   3463 non-null   object
#  10  team1_player11   3463 non-null   object
#  11  team2_players1   3463 non-null   object
#  12  team2_players2   3463 non-null   object
#  13  team2_players3   3463 non-null   object
#  14  team2_players4   3463 non-null   object
#  15  team2_players5   3463 non-null   object
# ...

# %%
matches.head()
# Out:
#        team1      team2 gender   season        date  \
# 0  Australia  Sri Lanka   male  2016/17  2017/02/17
# 1  Australia  Sri Lanka   male  2016/17  2017/02/19
# 2  Australia  Sri Lanka   male  2016/17  2017/02/22
# 3    Ireland  Hong Kong   male     2016  2016/09/05
# 4   Zimbabwe      India   male     2016  2016/06/18
#
#                                venue         city toss_winner toss_decision  \
# 0           Melbourne Cricket Ground         None   Sri Lanka         field
# 1     Simonds Stadium, South Geelong     Victoria   Sri Lanka         field
# 2                      Adelaide Oval         None   Sri Lanka         field
# 3  Bready Cricket Club, Magheramason  Londonderry   Hong Kong           bat
# 4                 Harare Sports Club         None       India         field
#
#       winner  match_id
# 0  Sri Lanka   1001349
# 1  Sri Lanka   1001351
# 2  Australia   1001353
# 3  Hong Kong   1004729
# 4   Zimbabwe   1007655

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   team1          3463 non-null   object
#  1   team2          3463 non-null   object
#  2   gender         3463 non-null   object
#  3   season         3463 non-null   object
#  4   date           3463 non-null   object
#  5   venue          3463 non-null   object
#  6   city           3271 non-null   object
#  7   toss_winner    3463 non-null   object
#  8   toss_decision  3463 non-null   object
#  9   winner         3463 non-null   object
#  10  match_id       3463 non-null   int64
# dtypes: int64(1), object(10)
# memory usage: 297.7+ KB

# %%
matches.head()
# Out:
#        team1      team2 gender   season        date  \
# 0  Australia  Sri Lanka   male  2016/17  2017/02/17
# 1  Australia  Sri Lanka   male  2016/17  2017/02/19
# 2  Australia  Sri Lanka   male  2016/17  2017/02/22
# 3    Ireland  Hong Kong   male     2016  2016/09/05
# 4   Zimbabwe      India   male     2016  2016/06/18
#
#                                venue         city toss_winner toss_decision  \
# 0           Melbourne Cricket Ground         None   Sri Lanka         field
# 1     Simonds Stadium, South Geelong     Victoria   Sri Lanka         field
# 2                      Adelaide Oval         None   Sri Lanka         field
# 3  Bready Cricket Club, Magheramason  Londonderry   Hong Kong           bat
# 4                 Harare Sports Club         None       India         field
#
#       winner  match_id
# 0  Sri Lanka   1001349
# 1  Sri Lanka   1001351
# 2  Australia   1001353
# 3  Hong Kong   1004729
# 4   Zimbabwe   1007655

# %%
deliveries = deliveries.merge(matches[['match_id', 'toss_winner', 'toss_decision', 'winner', 'venue', 'season']],on='match_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 deliveries = deliveries.merge(matches[['match_id', 'toss_winner', 'toss_decision', 'winner', 'venue', 'season']],on='match_id', how='left')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:10805, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10786 @Substitution("")
#   10787 @Appender(_merge_doc, indents=2)
#   10788 def merge(
#    (...)
#   10801     validate: MergeValidate | None = None,
#   10802 ) -> DataFrame:
#   10803     from pandas.core.reshape.merge import merge
# > 10805     return merge(
#   10806         self,
#   10807         right,
#   10808         how=how,
#   10809         on=on,
# ...

# %%
deliveries.head()
# Out:
#    match_id season_x  start_date                   venue_x  innings  ball  \
# 0   1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.1
# 1   1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.2
# 2   1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.3
# 3   1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.4
# 4   1001349  2016/17  2017-02-17  Melbourne Cricket Ground        1   0.5
#
#   batting_team bowling_team    striker non_striker  ... season_y  \
# 0    Australia    Sri Lanka   AJ Finch   M Klinger  ...  2016/17
# 1    Australia    Sri Lanka   AJ Finch   M Klinger  ...  2016/17
# 2    Australia    Sri Lanka   AJ Finch   M Klinger  ...  2016/17
# 3    Australia    Sri Lanka  M Klinger    AJ Finch  ...  2016/17
# 4    Australia    Sri Lanka  M Klinger    AJ Finch  ...  2016/17
#
#    total_runs_x  total_wickets_x  toss_winner_y toss_decision_y   winner_y  \
# ...

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794009 entries, 0 to 794008
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   match_id                794009 non-null  int64
#  1   season_x                794009 non-null  object
#  2   start_date              794009 non-null  object
#  3   venue_x                 794009 non-null  object
#  4   innings                 794009 non-null  int64
#  5   ball                    794009 non-null  float64
#  6   batting_team            794009 non-null  object
#  7   bowling_team            794009 non-null  object
#  8   striker                 794009 non-null  object
#  9   non_striker             794009 non-null  object
#  10  bowler                  794009 non-null  object
#  11  runs_off_bat            794009 non-null  int64
#  12  extras                  794009 non-null  int64
#  13  wides                   32436 non-null   float64
# ...

# %%
# Calculate player-level statistics
player_stats = deliveries.groupby(['match_id', 'striker']).agg({
    'runs_off_bat': 'sum',
    'player_dismissed': lambda x: (x.notna()).sum()  # Counting dismissals
}).reset_index()
player_stats.rename(columns={'runs_off_bat': 'total_runs', 'player_dismissed': 'total_wickets'}, inplace=True)

# %%
player_stats
# Out:
#        match_id         striker  total_runs  total_wickets
# 0        211028      A Flintoff           6              1
# 1        211028       A Symonds           0              1
# 2        211028    AC Gilchrist          15              1
# 3        211028      AJ Strauss          18              1
# 4        211028           B Lee          15              1
# ...         ...             ...         ...            ...
# 54781   1441145        RR Patel          15              1
# 54782   1441145         S Singh          41              1
# 54783   1441145       SO Ngoche          31              0
# 54784   1441145  Tanzeel Sheikh           4              1
# 54785   1441145      Yves Cyusa          24              1
#
# [54786 rows x 4 columns]

# %%
# Merge player statistics back to deliveries
deliveries = deliveries.merge(player_stats, how='left', left_on=['match_id', 'striker'], right_on=['match_id', 'striker'])

# %%
# Calculate team strength indicators
def calculate_team_strength(players, stats):
    return players.applymap(lambda player: stats[stats['striker'] == player]['total_runs'].mean()).mean(axis=1)

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794009 entries, 0 to 794008
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   match_id                794009 non-null  int64
#  1   season_x                794009 non-null  object
#  2   start_date              794009 non-null  object
#  3   venue_x                 794009 non-null  object
#  4   innings                 794009 non-null  int64
#  5   ball                    794009 non-null  float64
#  6   batting_team            794009 non-null  object
#  7   bowling_team            794009 non-null  object
#  8   striker                 794009 non-null  object
#  9   non_striker             794009 non-null  object
#  10  bowler                  794009 non-null  object
#  11  runs_off_bat            794009 non-null  int64
#  12  extras                  794009 non-null  int64
#  13  wides                   32436 non-null   float64
# ...

# %%
import pandas as pd

# Assuming deliveries, matches, and match_players DataFrames are already loaded.

# Step 1: Calculate average runs scored by each player in previous matches
player_average_runs = deliveries.groupby('striker')['total_runs'].mean().reset_index()
player_average_runs.rename(columns={'total_runs': 'average_runs'}, inplace=True)

# Step 2: Map average runs back to the players in match_players DataFrame
for i in range(1, 12):
    match_players[f'team1_player{i}_strength'] = match_players[f'team1_player{i}'].map(player_average_runs.set_index('striker')['average_runs'])
    match_players[f'team2_player{i}_strength'] = match_players[f'team2_players{i}'].map(player_average_runs.set_index('striker')['average_runs'])

# Step 3: Calculate team strength as the average of player strengths
match_players['team1_strength'] = match_players[[f'team1_player{i}_strength' for i in range(1, 12)]].mean(axis=1)
match_players['team2_strength'] = match_players[[f'team2_player{i}_strength' for i in range(1, 12)]].mean(axis=1)

# Step 4: Add team strength indicators to the main deliveries dataset
deliveries = deliveries.merge(match_players[['match_id', 'team1_strength', 'team2_strength']], on='match_id', how='left')

# The deliveries DataFrame now has the team strength indicators

# %%
deliveries.info()

# %%
features = ['total_runs', 'total_wickets', 'team1_strength', 'team2_strength','venue', 'season']

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   team1          3463 non-null   object
#  1   team2          3463 non-null   object
#  2   gender         3463 non-null   object
#  3   season         3463 non-null   object
#  4   date           3463 non-null   object
#  5   venue          3463 non-null   object
#  6   city           3271 non-null   object
#  7   toss_winner    3463 non-null   object
#  8   toss_decision  3463 non-null   object
#  9   winner         3463 non-null   object
#  10  match_id       3463 non-null   int64
# dtypes: int64(1), object(10)
# memory usage: 297.7+ KB

# %%
deliveries['match_id']
# Out:
# 0         1001349
# 1         1001349
# 2         1001349
# 3         1001349
# 4         1001349
#            ...
# 794004     995469
# 794005     995469
# 794006     995469
# 794007     995469
# 794008     995469
# Name: match_id, Length: 794009, dtype: int64

# %%
deliveries = deliveries.merge(matches[['winner','match_id']], on='match_id', how='left')

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794009 entries, 0 to 794008
# Data columns (total 41 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   match_id                794009 non-null  int64
#  1   season_x                794009 non-null  object
#  2   start_date              794009 non-null  object
#  3   venue_x                 794009 non-null  object
#  4   innings                 794009 non-null  int64
#  5   ball                    794009 non-null  float64
#  6   batting_team            794009 non-null  object
#  7   bowling_team            794009 non-null  object
#  8   striker                 794009 non-null  object
#  9   non_striker             794009 non-null  object
#  10  bowler                  794009 non-null  object
#  11  runs_off_bat            794009 non-null  int64
#  12  extras                  794009 non-null  int64
#  13  wides                   32436 non-null   float64
# ...

# %%
deliveries.isnull().sum()

# %%
X = deliveries[features].fillna(0)  # Handle missing values
y = (deliveries['winner'] == deliveries['bowling_team']).astype(int)

# %%
y
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 794004    0
# 794005    0
# 794006    0
# 794007    0
# 794008    0
# Length: 794009, dtype: int32

# %%
X
# Out:
#         total_runs  total_wickets  team1_strength  team2_strength  \
# 0               43              1       22.924737       20.047656
# 1               43              1       22.924737       20.047656
# 2               43              1       22.924737       20.047656
# 3               38              1       22.924737       20.047656
# 4               38              1       22.924737       20.047656
# ...            ...            ...             ...             ...
# 794004           9              0       25.103520       25.081995
# 794005           3              0       25.103520       25.081995
# 794006           9              0       25.103520       25.081995
# 794007           9              0       25.103520       25.081995
# 794008           9              0       25.103520       25.081995
#
#                            venue   season
# 0       Melbourne Cricket Ground  2016/17
# 1       Melbourne Cricket Ground  2016/17
# 2       Melbourne Cricket Ground  2016/17
# ...
